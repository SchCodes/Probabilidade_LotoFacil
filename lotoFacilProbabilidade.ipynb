# %%
import leganalise as leg
import pandas as pd

# %%
loto = leg.analise()

# %%
loto.coletar_dados()
# Out:
# Último concurso registrado: 3208
# Número do Concurso: 3208
# Data do Concurso: 30/09/2024
# Concurso 3208 já registrado. Finalizando a coleta.
# Nenhum sorteio novo foi coletado.

# %%
loto.dados
# Out:
#       Concurso        Data  Número_1  Número_2  Número_3  Número_4  Número_5  \
# 0         3208  30/09/2024         1         6         8         9        10
# 1         3207  28/09/2024         1         2         3         4         6
# 2         3206  27/09/2024         4         5         7         9        10
# 3         3205  26/09/2024         1         3         4         7         8
# 4         3204  25/09/2024         2         3         5         6        11
# ...        ...         ...       ...       ...       ...       ...       ...
# 3203         2  06/10/2003         1         4         5         6         7
# 3204         1  29/09/2003         2         3         5         6         9
# 3205      2538  03/06/2022         1         2         4         5         6
# 3206      1588  20/11/2017         1         3         4         5         7
# 3207       904  13/05/2013         1         5         6         7         9
#
# ...

# %%
loto.calc_pares_trincas_quadras()

# %%
loto.pares_df.head(10)

# %%
loto.calcular_frequencia_amostra(16)
# Out:
# {25: 14,
#  20: 13,
#  4: 13,
#  12: 12,
#  13: 12,
#  19: 11,
#  22: 11,
#  2: 11,
#  6: 10,
#  10: 10,
#  23: 10,
#  24: 10,
#  8: 9,
#  9: 9,
#  18: 9,
#  3: 9,
#  11: 9,
#  1: 8,
#  15: 8,
#  17: 8,
#  5: 8,
#  21: 8,
#  16: 7,
#  14: 6,
#  7: 5}

# %%
loto.dados
